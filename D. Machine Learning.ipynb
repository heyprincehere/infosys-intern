# %% [markdown]
# # Machine Learning

# %%
# Import required packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

sns.set()

# %%
# Read the previous csv file as dataframe
df = pd.read_csv('data.csv').drop(['Unnamed: 0'],axis=1)
df.head()
# Out:
#   InvoiceDate StockCode  Quantity  TotalPrice  Week  Weekday  Day
# 0  2010-12-01     10002        60       51.00    48        2    1
# 1  2010-12-01     10125         2        1.70    48        2    1
# 2  2010-12-01     10133         5        4.25    48        2    1
# 3  2010-12-01    15044B         1        2.95    48        2    1
# 4  2010-12-01   15056BL        20      113.00    48        2    1

# %% [markdown]
# #### Our final dataset is ready to carry out machine learning operations.

# %% [markdown]
# ## Machine Learning Process and Methodology
#
# To find the best model for our purpose, we will train our data on different algorithms, compare their performance based on the Root mean square error of the prediction and time taken to fit/predict the model, and select the best.
#
# ### Algorithms employed:
# 1. Linear Regression
# 2. Regularization Model - Ridge
# 3. Regularization Model - Lasso
# 4. Ensemble Model - Random Forest
# 1. Ensemble Model - Gradient Boost
# 1. Ensemble Model - Ada Boost
#
# After training and evaluating our data on the above algorithms, we will also use model stacking.
#
# 7. Stack - Linear Regression
# 8. Stack - Random Forest
# 9. Stack - Gradient Boost

# %% [markdown]
# ### Train-test split
#
# We will hold out the data for last month from Nov-01-2011 to Dec-09-2011 as our test set, and the remaining data will be used to train our model.

# %%
# Split the dataset into train and test dataset

df_train = df[df.InvoiceDate<'2011-11-01']
df_test = df[df.InvoiceDate>='2011-11-01']

# %%
df_train.head()
# Out:
#   InvoiceDate StockCode  Quantity  TotalPrice  Week  Weekday  Day
# 0  2010-12-01     10002        60       51.00    48        2    1
# 1  2010-12-01     10125         2        1.70    48        2    1
# 2  2010-12-01     10133         5        4.25    48        2    1
# 3  2010-12-01    15044B         1        2.95    48        2    1
# 4  2010-12-01   15056BL        20      113.00    48        2    1

# %%
# Define the feature and target variables

X_train = df_train.drop(labels=['InvoiceDate','StockCode','Quantity','TotalPrice'],axis=1)
y_train = df_train.Quantity

X_test = df_test.drop(labels=['InvoiceDate','StockCode','Quantity','TotalPrice'],axis=1)
y_test = df_test.Quantity

# %%
# Data Frame to store all the RMSE scores for various algorithms
algo_score = pd.DataFrame()
algo_score.index.name = 'Modelling Algo'
algo_score['Train RMSE'] = None
algo_score['Test RMSE'] = None
algo_score['Hyperparameters'] = None
algo_score['Training+Test Time(sec)'] = None

cv_time = []

# Dataframes for second level of predictions. Collect the predicted y values for training and test set of data
ypred_train = pd.DataFrame(index = X_train.index)
ypred_test = pd.DataFrame(index = X_test.index)

ypred_train['quantity'], ypred_test['quantity'] = y_train, y_test

# %% [markdown]
# We will define functions to measure the model, apply cross validation, and predict on train and test datasets. We have not included model fitting in the functions as that will happen as part of hyperparameter tuning

# %%
from sklearn.metrics import make_scorer

# Metric used to measure the model (Root Mean Square Error)
def rmse(y_actual, y_pred):
    rmse = np.sqrt(mean_squared_error(y_actual,y_pred))
    return rmse
rmse_cv = make_scorer(rmse, greater_is_better=False)

# %% [markdown]
# plot_true_vs_pred: This is used to plot True and Predicted count values for a particular time interval

# %%
# Plots True vs. Predicted count values
def plot_true_vs_pred (y_actual, y_pred):
    fig = plt.figure(figsize=(18, 16))
    
    pred_val = pd.DataFrame({'actual':y_actual,'predicted':y_pred})
    pred_val['error']=abs(pred_val.actual-pred_val.predicted)
    sns.swarmplot(pred_val.actual.round(0),pred_val.error)
    
    plt.show()

# %%
# Function to predict on train and test data and return the required metrics
def model_fit(model, X_train, y_train, X_test, y_test):
    ''' 
    Input:
        model = model to be applied
        X_train y_train = Training data
        X_test, y_test = Testing data
    Output:
        rmse for training and test data 
        predicted y for training and test data
    
    '''
#     model.fit(X_train, y_train)
    y_train_predict = model.predict(X_train)
    y_test_predict = model.predict(X_test)
    
    rmse_train = rmse(y_train, y_train_predict)
    rmse_test = rmse(y_test, y_test_predict)
    
    rmse_all = [rmse_train, rmse_test]
    y_pred_all = [y_train_predict, y_test_predict]
    
    return(rmse_all, y_pred_all)

# %%
from sklearn.model_selection import cross_val_predict
def cross_val(model, X_train, y_train, cv=5):
#     y_pred = pd.Series(index=y_train.index)
    y_pred = cross_val_predict(model,X_train,y_train,cv=5)

    rmse_train = rmse(y_train,y_pred)
    return(rmse_train, y_pred)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

param_summary = ['','']

# %time reg.fit(X_train, y_train)
# %time rmse_summary, y_predict_summary = model_fit(reg, X_train, y_train, X_test, y_test)

ypred_test['LR'] = y_predict_summary[1]  
ypred_train['LR'] = y_predict_summary[0]

algo_score.loc['Linear Regression'] = rmse_summary+param_summary
# Out:
# CPU times: total: 0 ns
# Wall time: 17.6 ms
# CPU times: total: 0 ns
# Wall time: 11.5 ms

# %%
algo_score.loc['Linear Regression', 'Training+Test Time(sec)'] = 0.516
cv_time.append(0.516)
algo_score
# Out:
#                    Train RMSE  Test RMSE Hyperparameters  \
# Modelling Algo
# Linear Regression   25.431848  26.443285
#
#                   Training+Test Time(sec)
# Modelling Algo
# Linear Regression                   0.516

# %% [markdown]
# #### Observations
#
# Not an overfit model - both train and test RMSE are more or less similar

# %%
import joblib
joblib.dump(reg, 'Linear_regresssion.pkl')
# Out:
# ['Linear_regresssion.pkl']

# %%
# Features and the Estimated Linear Regression Coefficients
df_coeff = pd.DataFrame({'features': X_train.columns, 'Lin_Coeff': reg.coef_})

# %%
# Linear Regression Plot: True vs. Predicted
# plot_true_vs_pred(y_test,y_predict_summary[1])

# %% [markdown]
# ### Regularization Model - Ridge

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# Hyperparameter Tuning
param_grid = {'alpha': [0.1, 0.2, 0.5, 1, 2, 5, 10, 20, 50, 100]}
ridge = GridSearchCV(Ridge(random_state=42), param_grid, cv=5, scoring=rmse_cv)
# %time ridge.fit(X_train, y_train)
print('Best alpha for Ridge Regression Model: {}'.format(ridge.best_params_))
# Out:
# CPU times: total: 281 ms
# Wall time: 2.03 s
# Best alpha for Ridge Regression Model: {'alpha': 100}

# %%
# Fine tune Hyperparameter for edge cases
param_grid = {'alpha': np.arange(75,150,10)}
ridge = GridSearchCV(Ridge(random_state=42), param_grid, cv=5, scoring=rmse_cv)
# %time ridge.fit(X_train, y_train)
print('Best alpha for Ridge Regression Model: {}'.format(ridge.best_params_))
# Out:
# CPU times: total: 531 ms
# Wall time: 3.1 s
# Best alpha for Ridge Regression Model: {'alpha': 145}

# %%
param_summary = [ridge.best_params_,'']

# %time rmse_summary, y_predict_summary = model_fit(ridge, X_train, y_train, X_test, y_test)

ypred_test['Ridge'] = y_predict_summary[1]  
ypred_train['Ridge'] = y_predict_summary[0]

algo_score.loc['Ridge Regression'] = rmse_summary+param_summary
# Out:
# CPU times: total: 0 ns
# Wall time: 24.4 ms

# %%
algo_score.loc['Ridge Regression', 'Training+Test Time(sec)'] = 6.917
cv_time.append(6.917)
algo_score
# Out:
#                    Train RMSE  Test RMSE Hyperparameters  \
# Modelling Algo
# Linear Regression   25.431848  26.443285
# Ridge Regression    25.431848  26.443280  {'alpha': 145}
#
#                   Training+Test Time(sec)
# Modelling Algo
# Linear Regression                   0.516
# Ridge Regression                    6.917

# %% [markdown]
# #### Observations
#
# Ridge gives almost similar performance as Linear Regression. It is not an overfit model

# %%
joblib.dump(ridge, 'Ridge_Regression.pkl')
# Out:
# ['Ridge_Regression.pkl']

# %%
# Features and the Estimated Ridge Regression Coefficients
df_coeff['Ridge_Coeff'] = ridge.best_estimator_.coef_

# %%
# plot_true_vs_pred(y_test,y_predict_summary[1])

# %% [markdown]
# ### Regularization Model - Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# Hyperparameter Tuning
param_grid = {'alpha': [0.1, 0.2, 0.5, 1, 2, 5, 10, 20, 50, 100]}
lasso = GridSearchCV(Lasso(random_state=42), param_grid, cv=5, scoring=rmse_cv)
# %time lasso.fit(X_train, y_train)
print('Best alpha for Lasso Regression Model: {}'.format(lasso.best_params_))
# Out:
# CPU times: total: 1min 24s
# Wall time: 1min 13s
# Best alpha for Lasso Regression Model: {'alpha': 0.1}

# %%
# Fine tune Hyperparameter for edge case

param_grid = {'alpha': np.arange(.01,.25,.01)}
lasso = GridSearchCV(Lasso(random_state=42), param_grid, cv=5, scoring=rmse_cv)
# %time lasso.fit(X_train, y_train)
print('Best alpha for Lasso Regression Model: {}'.format(lasso.best_params_))
# Out:
# CPU times: total: 2min 28s
# Wall time: 1min 54s
# Best alpha for Lasso Regression Model: {'alpha': 0.01}

# %%
param_summary = [lasso.best_params_,'']

# %time rmse_summary, y_predict_summary = model_fit(lasso, X_train, y_train, X_test, y_test)
ypred_test['Lasso'] = y_predict_summary[1]
ypred_train['Lasso'] = y_predict_summary[0]

algo_score.loc['Lasso Regression'] = rmse_summary+param_summary
# Out:
# CPU times: total: 15.6 ms
# Wall time: 20.3 ms

# %%
algo_score.loc['Lasso Regression', 'Training+Test Time(sec)'] = 31.328
cv_time.append(31.328)
algo_score
# Out:
#                    Train RMSE  Test RMSE  Hyperparameters  \
# Modelling Algo
# Linear Regression   25.431848  26.443285
# Ridge Regression    25.431848  26.443280   {'alpha': 145}
# Lasso Regression    25.431848  26.443164  {'alpha': 0.01}
#
#                   Training+Test Time(sec)
# Modelling Algo
# Linear Regression                   0.516
# Ridge Regression                    6.917
# Lasso Regression                   31.328

# %% [markdown]
# #### Observations
#
# Lasso regression also shows almost similar performance as Linear and Ridge regression

# %%
joblib.dump(lasso, 'lasso_Regression.pkl')
# Out:
# ['lasso_Regression.pkl']

# %%
# Features and the Estimated Lasso Regression Coefficients
df_coeff['Lasso_Coeff'] = lasso.best_estimator_.coef_

# %%
# plot_true_vs_pred(y_test,y_predict_summary[1])

# %% [markdown]
# ### Plotting the coefficients obtained from Linear, Ridge and Lasso regression

# %%
fig = plt.figure(figsize=(10, 5))

axes = fig.add_subplot(1, 1, 1)
axes.plot(df_coeff.Lin_Coeff, label='Linear Regression', marker='.', markersize=15)
axes.plot(df_coeff.Ridge_Coeff, label='Ridge Regression, alpha={}'.format(ridge.best_params_['alpha']), alpha=.5,marker='.', markersize=15)
axes.plot(df_coeff.Lasso_Coeff, label='Lasso Regression, alpha={}'.format(lasso.best_params_['alpha']), marker='.', markersize=15)

plt.xticks(range(len(df_coeff.Lin_Coeff)), df_coeff.features, rotation=90)
axes.set(ylabel='Estimated Regression Coefficients', title='Coefficients for different models')
axes.set(xlim=[-1, len(df_coeff.Lin_Coeff)])
axes.legend()

# %% [markdown]
# #### Observations
#
# As seen above, Weekday and UnitPrice are most important features

# %% [markdown]
# ### Ensemble Model - Random Forest

# %%
# Random Forest Regression Hyperparameter tuning using Grid Search to obtain the best parameters. 

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

# Example of parameter grid with correct max_features values
param_grid = {
    'max_features': ['sqrt', 'log2', None]  # Change 'auto' to valid options
}

# Set up RandomizedSearchCV
model = RandomForestRegressor()
rf_main = RandomizedSearchCV(model, param_grid, n_iter=10, random_state=42)
rf_main.fit(X_train, y_train)
# Out:
# C:\Users\sairi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(estimator=RandomForestRegressor(),
#                    param_distributions={'max_features': ['sqrt', 'log2', None]},
#                    random_state=42)

# %%
# Fit the RandomizedSearchCV object
# Make sure fit() is called before accessing best_params_

# Now access the best_params_
print('Best parameters for Random Forest Regression Model: {}'.format(rf_main.best_params_))
# Out:
# Best parameters for Random Forest Regression Model: {'max_features': 'log2'}

# %% [markdown]
# Best parameters for Random Forest Regression Model: {'n_jobs': -1, 'n_estimators': 500, 'min_samples_leaf': 50, 'max_features': 'auto'}

# %%
param_summary = [rf_main.best_params_,'']

# %time rmse_summary, y_predict_summary = model_fit(rf_main, X_train, y_train, X_test, y_test)
ypred_test['RF'] = y_predict_summary[1]
ypred_train['RF'] = y_predict_summary[0]

algo_score.loc['Random Forest'] = rmse_summary+param_summary
# Out:
# CPU times: total: 594 ms
# Wall time: 1.46 s

# %%
algo_score.loc['Random Forest', 'Training+Test Time(sec)'] = 6706
cv_time.append(6706)
algo_score
# Out:
#                    Train RMSE  Test RMSE           Hyperparameters  \
# Modelling Algo
# Linear Regression   25.431848  26.443285
# Ridge Regression    25.431848  26.443280            {'alpha': 145}
# Lasso Regression    25.431848  26.443164           {'alpha': 0.01}
# Random Forest       25.110594  26.461514  {'max_features': 'log2'}
#
#                   Training+Test Time(sec)
# Modelling Algo
# Linear Regression                   0.516
# Ridge Regression                    6.917
# Lasso Regression                   31.328
# Random Forest                        6706

# %%
joblib.dump(rf_main, 'Random_Forest.pkl')
# Out:
# ['Random_Forest.pkl']

# %% [markdown]
# ### Visualize the mean score against different values for n estimators
#
# Parts of code have been commenting out as they take long time to execute

# %%
rf_result=pd.DataFrame(rf_main.cv_results_)
rf_result
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       4.041045      0.178584         0.171981        0.018504
# 1       4.063665      0.234066         0.194964        0.049845
# 2       6.686024      0.106637         0.178107        0.022362
#
#   param_max_features                    params  split0_test_score  \
# 0               sqrt  {'max_features': 'sqrt'}           0.004017
# 1               log2  {'max_features': 'log2'}           0.003917
# 2               None    {'max_features': None}          -0.011954
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.010982           0.005855           0.002172           0.012283
# 1          -0.007702           0.006169           0.001324           0.011453
# 2          -0.001945           0.000951          -0.002351           0.009518
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.002669        0.007629                2
# 1         0.003032        0.006319                1
# 2        -0.001156        0.006885                3

# %%
rf_result.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_max_features', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'split3_test_score',
#        'split4_test_score', 'mean_test_score', 'std_test_score',
#        'rank_test_score'],
#       dtype='object')

# %%
#est_score = rf_result.groupby('params')['mean_test_score'].mean()
#est_score

# %%
fig=plt.figure(figsize=(18, 12))

axes=fig.add_subplot(2, 3, 1)
axes.plot(est_score.index, est_score.values, marker='.')
axes.set(xlabel='n_estimators', ylabel='Mean CV Test Score', title='n_estimators vs. Score (best_n_estimator = 500)')
# Out:
# [Text(0.5, 0, 'n_estimators'),
#  Text(0, 0.5, 'Mean CV Test Score'),
#  Text(0.5, 1.0, 'n_estimators vs. Score (best_n_estimator = 500)')]

# %%
fig = plt.figure(figsize=(18, 8))
axes = fig.add_subplot(1, 1, 1)
axes.plot(rf_main.best_estimator_.feature_importances_, marker='.', markersize=15)
plt.xticks(range(len(rf_main.best_estimator_.feature_importances_)), X_train.columns,rotation=90)
axes.set(ylabel='Feature Importance', title='Feature Importance for Random Forest Regression')

plt.show()

# %% [markdown]
# ### Ensemble Method - Gradient Boost

# %%
# The code for hyperparameter tuning is commented out as it takes a long time to run 

# Tuning the hyperparameters

from sklearn.ensemble import GradientBoostingRegressor

param_distributions = param_distributions = {
    'n_estimators': [50, 100, 500, 1000],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_features': ['sqrt', 'log2', None],  # Corrected value for max_features
    'min_samples_leaf': [1, 3, 7, 10],
    'min_samples_split': [2, 5, 10]
}

grad_boost = RandomizedSearchCV(GradientBoostingRegressor(random_state=42), param_distributions, verbose=2, n_iter = 100,cv=5, scoring=rmse_cv)
grad_boost.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  38.2s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  37.2s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  36.5s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  37.5s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  38.3s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  20.6s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  23.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  23.5s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  22.2s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=1000; total time=  23.5s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  18.7s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  18.6s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  19.3s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  19.3s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  20.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  23.9s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  22.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  22.8s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  25.5s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  24.6s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   3.6s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   3.7s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   3.7s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   3.8s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   3.6s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  24.0s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  23.2s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  24.9s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  24.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  23.7s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  11.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  11.5s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  11.7s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  13.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  13.0s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  28.6s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  26.6s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  23.7s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  23.2s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  25.3s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  20.0s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  19.2s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  19.5s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  19.1s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  20.6s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  12.4s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  12.9s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  12.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  13.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  13.4s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   2.2s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   2.0s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   2.1s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   2.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  26.8s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  27.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  25.8s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  28.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  26.9s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  21.4s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  21.0s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  19.5s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  19.4s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  20.0s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.0s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.0s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.6s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.8s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.5s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=100; total time=   4.8s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=100; total time=   4.1s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=100; total time=   4.0s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  13.1s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  12.4s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  12.0s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  11.8s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  11.7s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  24.6s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  24.0s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  24.2s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  24.7s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=1000; total time=  24.7s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  39.1s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  38.4s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  37.4s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  39.1s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=  39.6s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  11.9s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  12.0s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  11.6s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  12.0s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  12.3s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  19.4s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  19.5s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  19.1s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  17.7s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  18.8s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  24.5s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  24.4s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  23.9s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  24.6s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=1000; total time=  24.0s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  39.2s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  38.3s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  36.3s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  39.8s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  39.4s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  12.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  12.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  12.3s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  12.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500; total time=  11.9s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  22.7s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  22.2s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  24.5s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  23.9s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  24.5s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  23.7s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  23.9s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  23.7s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  24.3s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=1000; total time=  23.7s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   1.6s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.6s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.6s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  18.0s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  20.4s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  18.4s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  18.0s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=500; total time=  18.6s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  11.3s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  11.2s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  11.5s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  11.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  11.2s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  24.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  23.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  22.3s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  22.2s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  24.6s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.01, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  11.3s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  12.3s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  11.5s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  11.9s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  11.9s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=  18.6s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=  19.0s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=  19.6s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=  19.9s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=  20.1s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   2.5s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   2.3s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   2.4s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   2.4s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   2.0s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=5, n_estimators=50; total time=   2.0s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  21.3s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  21.4s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  20.2s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  20.6s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  19.4s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=2, n_estimators=100; total time=   3.7s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=2, n_estimators=100; total time=   3.6s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=2, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=2, n_estimators=100; total time=   3.9s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=7, min_samples_split=2, n_estimators=100; total time=   4.0s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  24.7s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  24.2s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  23.9s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  23.6s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  22.7s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  21.3s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  24.8s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  23.6s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  23.3s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=  23.6s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  11.3s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  11.5s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  11.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  12.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  11.6s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  12.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  11.7s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  11.3s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  11.1s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=500; total time=  10.9s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  17.2s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  19.7s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  19.4s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  18.3s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  18.3s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   3.6s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   3.5s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   3.8s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   1.6s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.01, max_features=None, min_samples_leaf=10, min_samples_split=10, n_estimators=50; total time=   1.7s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   1.8s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  11.3s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  11.6s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  11.3s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  12.2s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  12.5s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  21.9s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  20.9s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  23.3s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  23.6s
# [CV] END learning_rate=0.1, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; total time=  23.0s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  36.7s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  37.1s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  39.1s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  36.8s
# [CV] END learning_rate=0.1, max_features=None, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  36.4s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   2.7s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   2.5s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   2.6s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   2.5s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.8s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.5s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.6s
# [CV] END learning_rate=0.05, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.6s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  12.0s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  11.6s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  11.7s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  11.6s
# [CV] END learning_rate=0.01, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=  11.8s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  22.6s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  22.4s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  24.6s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  23.6s
# [CV] END learning_rate=0.05, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=1000; total time=  22.1s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END learning_rate=0.05, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.2s
# ...
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   3.8s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   3.4s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   3.4s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  54.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  29.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  53.6s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  29.4s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.05, total=  53.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.4s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.2s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.2s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total=   3.3s
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=10, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.2min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.2min
# [CV] n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=1000, min_samples_split=10, min_samples_leaf=1, max_features=auto, learning_rate=0.05, total= 1.4min
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  35.4s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  40.2s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  43.9s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  32.8s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=  48.1s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   6.4s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   6.1s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   6.2s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   6.0s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=7, max_features=auto, learning_rate=0.05, total=   8.5s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  18.5s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=  14.9s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   6.8s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   7.0s
# [CV] n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.01, total=   7.1s
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=1000, min_samples_split=5, min_samples_leaf=1, max_features=auto, learning_rate=0.01, total= 1.4min
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.0s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.0s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.1s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.3s
# [CV] n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=50, min_samples_split=2, min_samples_leaf=3, max_features=auto, learning_rate=0.1, total=   3.0s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  43.0s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  37.3s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  47.0s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  31.8s
# [CV] n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=2, min_samples_leaf=10, max_features=auto, learning_rate=0.1, total=  44.4s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  11.5s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.4s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=   6.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=   7.2s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=   7.0s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=  16.9s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=  19.4s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_features=auto, learning_rate=0.01, total=   7.6s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  29.7s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  54.9s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  29.4s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  54.4s
# [CV] n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1
# [CV]  n_estimators=500, min_samples_split=10, min_samples_leaf=7, max_features=auto, learning_rate=0.1, total=  29.4s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed: 479.7min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_sampl...te=42, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False),
#           fit_params=None, iid='warn', n_iter=100, n_jobs=None,
#           param_distributions={'n_estimators': [50, 100, 500, 1000], 'learning_rate': [0.01, 0.05, 0.1], 'max_features': ['auto'], 'min_samples_leaf': [1, 3, 7, 10], 'min_samples_split': [2, 5, 10]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn',
#           scoring=make_scorer(rmse, greater_is_better=False), verbose=2)

# %%
joblib.dump(grad_boost, 'Gradient_Boost.pkl')
# Out:
# ['Gradient_Boost.pkl']

# %%
print('Best parameters for Gradient Boost Model: {}'.format(grad_boost.best_params_))
# Out:
# Best parameters for Gradient Boost Model: {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None, 'learning_rate': 0.05}

# %% [markdown]
# Best parameters for Gradient Boost Model: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 60, 'learning_rate': 0.01}

# %%
print('Best parameters for Gradient Boost Model: {}'.format(grad_boost.best_params_))
# Out:
# Best parameters for Gradient Boost Model: {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None, 'learning_rate': 0.05}

# %%
param_summary = [grad_boost.best_params_,'']

# %time rmse_summary, y_predict_summary = model_fit(grad_boost, X_train, y_train, X_test, y_test)
ypred_test['GB'] = y_predict_summary[1]
ypred_train['GB'] = y_predict_summary[0]

algo_score.loc['Gradient Boost'] = rmse_summary+param_summary
# Out:
# CPU times: total: 141 ms
# Wall time: 217 ms

# %%
algo_score.loc['Gradient Boost', 'Training+Test Time(sec)'] = 89.796
cv_time.append(89.796)
algo_score
# Out:
#                    Train RMSE  Test RMSE  \
# Modelling Algo
# Linear Regression   25.431848  26.443285
# Ridge Regression    25.431848  26.443280
# Lasso Regression    25.431848  26.443164
# Random Forest       25.110594  26.461514
# Gradient Boost      25.293174  26.409518
#
#                                                      Hyperparameters  \
# Modelling Algo
# Linear Regression
# Ridge Regression                                      {'alpha': 145}
# Lasso Regression                                     {'alpha': 0.01}
# Random Forest                               {'max_features': 'log2'}
# Gradient Boost     {'n_estimators': 50, 'min_samples_split': 10, ...
#
#                   Training+Test Time(sec)
# Modelling Algo
# Linear Regression                   0.516
# Ridge Regression                    6.917
# Lasso Regression                   31.328
# Random Forest                        6706
# Gradient Boost                     89.796

# %% [markdown]
# ### Visualize the mean score against different values for n estimators
#
# Parts of code have been commenting out as they take long time to execute

# %%
gb_result=pd.DataFrame(grad_boost.cv_results_)

gb_result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       37.366526      0.646623         0.272761        0.023202
# 1        1.083404      0.050434         0.025226        0.007626
# 2       22.471037      1.147340         0.284616        0.027144
# 3       19.124963      0.535475         0.148457        0.022276
# 4       23.601581      1.223229         0.270978        0.021822
# ..            ...           ...              ...             ...
# 95    1439.682079   2835.668028         0.264304        0.012902
# 96      35.957788      1.530764         0.270874        0.024746
# 97     303.651676    584.342758         0.142687        0.016584
# 98      35.928264      1.435853         0.273551        0.021501
# 99       3.453556      0.152017         0.027653        0.007246
#
#     param_n_estimators  param_min_samples_split  param_min_samples_leaf  \
# 0                 1000                       10                       7
# 1                   50                       10                      10
# 2                 1000                       10                       7
# 3                  500                       10                       7
# 4                 1000                       10                       3
# ..                 ...                      ...                     ...
# 95                1000                        5                       7
# 96                1000                        5                       7
# 97                 500                        2                      10
# 98                1000                        5                      10
# 99                 100                        5                       3
#
#    param_max_features  param_learning_rate  \
# 0                None                 0.01
# 1                log2                 0.10
# 2                log2                 0.01
# 3                None                 0.10
# 4                log2                 0.10
# ..                ...                  ...
# 95               sqrt                 0.01
# 96               None                 0.05
# 97               sqrt                 0.10
# 98               None                 0.05
# 99               None                 0.01
#
#                                                params  split0_test_score  \
# 0   {'n_estimators': 1000, 'min_samples_split': 10...         -24.878224
# 1   {'n_estimators': 50, 'min_samples_split': 10, ...         -24.734232
# 2   {'n_estimators': 1000, 'min_samples_split': 10...         -24.773817
# 3   {'n_estimators': 500, 'min_samples_split': 10,...         -25.045715
# 4   {'n_estimators': 1000, 'min_samples_split': 10...         -24.977668
# ..                                                ...                ...
# 95  {'n_estimators': 1000, 'min_samples_split': 5,...         -24.773817
# 96  {'n_estimators': 1000, 'min_samples_split': 5,...         -25.072802
# 97  {'n_estimators': 500, 'min_samples_split': 2, ...         -24.950809
# 98  {'n_estimators': 1000, 'min_samples_split': 5,...         -25.072802
# 99  {'n_estimators': 100, 'min_samples_split': 5, ...         -24.744754
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0          -25.121402         -25.900920         -26.057396
# 1          -24.510940         -25.873687         -26.027632
# 2          -24.680725         -25.886458         -26.032236
# 3          -25.328906         -25.978312         -26.101427
# 4          -25.291101         -26.010637         -26.108467
# ..                ...                ...                ...
# 95         -24.680725         -25.886458         -26.032236
# 96         -25.477441         -25.974915         -26.103022
# 97         -25.213767         -25.974307         -26.075526
# 98         -25.477441         -25.974915         -26.103022
# 99         -24.289864         -25.908687         -25.998053
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -25.966904       -25.584969        0.486471               70
# 1          -25.895692       -25.408437        0.647662               29
# 2          -25.941920       -25.463031        0.603264               52
# 3          -26.074682       -25.705809        0.434653               92
# 4          -26.083961       -25.694367        0.468950               87
# ..                ...              ...             ...              ...
# 95         -25.941920       -25.463031        0.603264               52
# 96         -26.068880       -25.739412        0.402299               96
# 97         -26.016560       -25.646194        0.468979               78
# 98         -26.068880       -25.739412        0.402299               96
# 99         -25.941724       -25.376616        0.716786                6
#
# [100 rows x 18 columns]

# %%
# gb_score = gb_result.groupby('param_n_estimators')['mean_test_score'].mean()
# gb_score

# %%
# fig=plt.figure(figsize=(18, 12))

# axes=fig.add_subplot(2, 3, 1)
# axes.plot(gb_score.index, gb_score.values, marker='.')
# axes.set(xlabel='n_estimators', ylabel='Mean CV Test Score', title='n_estimators vs. Score (best_n_estimator = 500)')

# %%
fig = plt.figure(figsize=(18, 8))
axes = fig.add_subplot(1, 1, 1)
axes.plot(grad_boost.best_estimator_.feature_importances_, marker='.', markersize=15)
plt.xticks(range(len(grad_boost.best_estimator_.feature_importances_)), X_train.columns,rotation=90)
axes.set(ylabel='Feature Importance', title='Feature Importance for Gradient Boost Regressor')
# axes.set(xlim=[-1, len(X_train.columns)], ylim=[0, 1])

plt.show()

# %% [markdown]
# ## SUMMARY AND CONCLUSIONS

# %% [markdown]
# ### RMSE

# %%
fig=plt.figure(figsize=(10, 6))
axes=fig.add_subplot(1, 1, 1)
bar_width = 0.3
idx = np.array(range(algo_score.shape[0]))
labels = algo_score.index
plt.bar(data=algo_score, height='Train RMSE', x=idx, color='g', width=bar_width, label='Training Data')
plt.bar(data=algo_score, height='Test RMSE', x=idx+bar_width, color='b', width=bar_width, label='Test Data')
plt.xticks(idx, labels, rotation=90)
plt.xlabel('Modelling Algorithms')
plt.ylabel('RMSE')
plt.title('Average RMSE for different Modelling Algorithms')
plt.legend()
plt.show()

# %% [markdown]
# From the above plot, we can see that Random Forest and Gradient Boost give us very similar and the best predictions with least RMSE. Comparing the train and test data predictions, the model seems to be be overfitted. But we are not much worried about it, as despite overfitting, we are getting good results on the test data.
#
# In order to decide between Random Forest and Gradient Boost, let us look at the time taken in fitting the model. In all the algorithms, the prediction time was very small in comparison to the fit time.

# %% [markdown]
# ### Train/Test Time

# %%
fig=plt.figure(figsize=(10, 6))
axes=fig.add_subplot(1, 1, 1)
bar_width = 0.6
idx = np.array(range(algo_score.shape[0]))
labels = algo_score.index
plt.bar(data=algo_score, height='Training+Test Time(sec)', x=idx, width=bar_width)
plt.xticks(idx, labels, rotation=90)
plt.xlabel('Modelling Algorithms')
plt.ylabel('Training+Test Time(sec)')
plt.title('Training Time + Test Time for different Models (sec)')
#axes.set_yscale('log')

plt.show()

# %% [markdown]
# As seen above, Gradient Boost is taking much lesser time as compared to Random Forest. So we choose Gradient Boost as our final algorithm.
# Gradient Boost gives an RMSE of 0.625 on our test data.

# %% [markdown]
# References:
#
# https://www.analyticsvidhya.com/blog/2018/06/comprehensive-guide-for-ensemble-models/
#
# https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
